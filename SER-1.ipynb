# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.1.5)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.19.5)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
# !pip install librosa==0.6.3
# Out:
# Collecting librosa==0.6.3
#   Downloading https://files.pythonhosted.org/packages/e9/7e/7a0f66f79a70a0a4c163ecf30429f6c1644c88654f135a9eee0bda457626/librosa-0.6.3.tar.gz (1.6MB)
#      |████████████████████████████████| 1.6MB 804kB/s
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.6.3) (2.1.9)
# Requirement already satisfied: numpy>=1.8.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.6.3) (1.19.5)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.6.3) (1.4.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.6.3) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.12 in /usr/local/lib/python3.7/dist-packages (from librosa==0.6.3) (1.0.1)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.6.3) (4.4.2)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/dist-packages (from librosa==0.6.3) (1.15.0)
# Requirement already satisfied: resampy>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.6.3) (0.2.2)
# Requirement already satisfied: numba>=0.38.0 in /usr/local/lib/python3.7/dist-packages (from librosa==0.6.3) (0.51.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.38.0->librosa==0.6.3) (54.0.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.38.0->librosa==0.6.3) (0.34.0)
# Building wheels for collected packages: librosa
#   Building wheel for librosa (setup.py) ... done
#   Created wheel for librosa: filename=librosa-0.6.3-cp37-none-any.whl size=1573318 sha256=7a629b16096f00cc6ca884f37c126656725f99750d768c98a79bd5365b89ff40
#   Stored in directory: /root/.cache/pip/wheels/ce/49/68/87ba660f30e3977f0778e39ee2e944629cd37c2a0ce41f9ff1
# Successfully built librosa
# Installing collected packages: librosa
#   Found existing installation: librosa 0.8.0
#     Uninstalling librosa-0.8.0:
#       Successfully uninstalled librosa-0.8.0
# Successfully installed librosa-0.6.3

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.19.5)

# %%
# !pip install soundfile==0.9.0
# Out:
# Collecting soundfile==0.9.0
#   Downloading https://files.pythonhosted.org/packages/f7/42/b8a6afe407eab72ea1f526fcfffd4f5f330203483956662fa9638fd45669/SoundFile-0.9.0-py2.py3-none-any.whl
# Requirement already satisfied: cffi>=0.6 in /usr/local/lib/python3.7/dist-packages (from soundfile==0.9.0) (1.14.5)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=0.6->soundfile==0.9.0) (2.20)
# Installing collected packages: soundfile
#   Found existing installation: SoundFile 0.10.3.post1
#     Uninstalling SoundFile-0.10.3.post1:
#       Successfully uninstalled SoundFile-0.10.3.post1
# Successfully installed soundfile-0.9.0

# %%
# !pip install sklearn
# Out:
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.0.1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.19.5)

# %%
# !pip install pyaudio==0.2.11
# Out:
# Collecting pyaudio==0.2.11
#   Downloading https://files.pythonhosted.org/packages/ab/42/b4f04721c5c5bfc196ce156b3c768998ef8c0ae3654ed29ea5020c749a6b/PyAudio-0.2.11.tar.gz
# Building wheels for collected packages: pyaudio
#   Building wheel for pyaudio (setup.py) ... error
#   ERROR: Failed building wheel for pyaudio
#   Running setup.py clean for pyaudio
# Failed to build pyaudio
# Installing collected packages: pyaudio
#     Running setup.py install for pyaudio ... error
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-7ui1eyy7/pyaudio/setup.py'"'"'; __file__='"'"'/tmp/pip-install-7ui1eyy7/pyaudio/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-ndmozqi7/install-record.txt --single-version-externally-managed --compile Check the logs for full command output.

# %%
# !pip install pyaudio
# Out:
# Collecting pyaudio
#   Using cached https://files.pythonhosted.org/packages/ab/42/b4f04721c5c5bfc196ce156b3c768998ef8c0ae3654ed29ea5020c749a6b/PyAudio-0.2.11.tar.gz
# Building wheels for collected packages: pyaudio
#   Building wheel for pyaudio (setup.py) ... error
#   ERROR: Failed building wheel for pyaudio
#   Running setup.py clean for pyaudio
# Failed to build pyaudio
# Installing collected packages: pyaudio
#     Running setup.py install for pyaudio ... error
# ERROR: Command errored out with exit status 1: /usr/bin/python3 -u -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-mhfs1zrl/pyaudio/setup.py'"'"'; __file__='"'"'/tmp/pip-install-mhfs1zrl/pyaudio/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-noz4wwxj/install-record.txt --single-version-externally-managed --compile Check the logs for full command output.

# %%
import soundfile
import numpy as np
import librosa
import glob
import os
import pickle
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-65d61580beed> in <module>()
#       1 import soundfile
#       2 import numpy as np
# ----> 3 import librosa
#       4 import glob
#       5 import os
#
# /usr/local/lib/python3.7/dist-packages/librosa/__init__.py in <module>()
#      10 # And all the librosa sub-modules
#      11 from . import cache
# ---> 12 from . import core
#      13 from . import beat
#      14 from . import decompose
#
# /usr/local/lib/python3.7/dist-packages/librosa/core/__init__.py in <module>()
#     107 """
#     108
# --> 109 from .time_frequency import *  # pylint: disable=wildcard-import
#     110 from .audio import *  # pylint: disable=wildcard-import
#     111 from .spectrum import *  # pylint: disable=wildcard-import
#
# /usr/local/lib/python3.7/dist-packages/librosa/core/time_frequency.py in <module>()
#       8 import six
#       9
# ---> 10 from ..util.exceptions import ParameterError
#      11
#      12 __all__ = ['frames_to_samples', 'frames_to_time',
#
# /usr/local/lib/python3.7/dist-packages/librosa/util/__init__.py in <module>()
#      69 from .matching import *  # pylint: disable=wildcard-import
#      70 from .deprecation import *  # pylint: disable=wildcard-import
# ---> 71 from . import decorators
#      72 from . import exceptions
#      73
#
# /usr/local/lib/python3.7/dist-packages/librosa/util/decorators.py in <module>()
#       7 from decorator import decorator
#       8 import six
# ----> 9 from numba.decorators import jit as optional_jit
#      10
#      11 __all__ = ['moved', 'deprecated', 'optional_jit']
#
# ModuleNotFoundError: No module named 'numba.decorators'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import librosa
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-989066361697> in <module>()
# ----> 1 import librosa
#
# /usr/local/lib/python3.7/dist-packages/librosa/__init__.py in <module>()
#      10 # And all the librosa sub-modules
#      11 from . import cache
# ---> 12 from . import core
#      13 from . import beat
#      14 from . import decompose
#
# /usr/local/lib/python3.7/dist-packages/librosa/core/__init__.py in <module>()
#     108
#     109 from .time_frequency import *  # pylint: disable=wildcard-import
# --> 110 from .audio import *  # pylint: disable=wildcard-import
#     111 from .spectrum import *  # pylint: disable=wildcard-import
#     112 from .pitch import *  # pylint: disable=wildcard-import
#
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py in <module>()
#      14 from .time_frequency import frames_to_samples, time_to_samples
#      15 from .. import cache
# ---> 16 from .. import util
#      17 from ..util.exceptions import ParameterError
#      18
#
# /usr/local/lib/python3.7/dist-packages/librosa/util/__init__.py in <module>()
#      69 from .matching import *  # pylint: disable=wildcard-import
#      70 from .deprecation import *  # pylint: disable=wildcard-import
# ---> 71 from . import decorators
#      72 from . import exceptions
#      73
#
# /usr/local/lib/python3.7/dist-packages/librosa/util/decorators.py in <module>()
#       7 from decorator import decorator
#       8 import six
# ----> 9 from numba.decorators import jit as optional_jit
#      10
#      11 __all__ = ['moved', 'deprecated', 'optional_jit']
#
# ModuleNotFoundError: No module named 'numba.decorators'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !apt-get install librosa==0.6.3
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# E: Unable to locate package librosa=

# %%
import librosa
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-20-989066361697> in <module>()
# ----> 1 import librosa
#
# /usr/local/lib/python3.7/dist-packages/librosa/__init__.py in <module>()
#      10 # And all the librosa sub-modules
#      11 from . import cache
# ---> 12 from . import core
#      13 from . import beat
#      14 from . import decompose
#
# /usr/local/lib/python3.7/dist-packages/librosa/core/__init__.py in <module>()
#     108
#     109 from .time_frequency import *  # pylint: disable=wildcard-import
# --> 110 from .audio import *  # pylint: disable=wildcard-import
#     111 from .spectrum import *  # pylint: disable=wildcard-import
#     112 from .pitch import *  # pylint: disable=wildcard-import
#
# /usr/local/lib/python3.7/dist-packages/librosa/core/audio.py in <module>()
#      14 from .time_frequency import frames_to_samples, time_to_samples
#      15 from .. import cache
# ---> 16 from .. import util
#      17 from ..util.exceptions import ParameterError
#      18
#
# /usr/local/lib/python3.7/dist-packages/librosa/util/__init__.py in <module>()
#      69 from .matching import *  # pylint: disable=wildcard-import
#      70 from .deprecation import *  # pylint: disable=wildcard-import
# ---> 71 from . import decorators
#      72 from . import exceptions
#      73
#
# /usr/local/lib/python3.7/dist-packages/librosa/util/decorators.py in <module>()
#       7 from decorator import decorator
#       8 import six
# ----> 9 from numba.decorators import jit as optional_jit
#      10
#      11 __all__ = ['moved', 'deprecated', 'optional_jit']
#
# ModuleNotFoundError: No module named 'numba.decorators'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
